# %%
import pandas as pd

# %%
df = pd.read_csv('CPCB_DATA.csv')

# %%
df.head()
# Out:
#           From Date           To Date   PM2.5    PM10     NO    NO2    NOx  \
# 0  01-01-2024 00:00  01-01-2024 04:00  173.22  266.89  65.59  76.85  93.94
# 1  01-01-2024 04:00  01-01-2024 08:00  119.92  203.37   8.42  28.28  22.27
# 2  01-01-2024 08:00  01-01-2024 12:00  110.05  183.18   7.01  36.94  26.06
# 3  01-01-2024 12:00  01-01-2024 16:00  105.07  163.57   5.57  22.86  17.44
# 4  01-01-2024 16:00  01-01-2024 20:00   88.36  138.50  48.31  84.38  83.95
#
#      NH3    SO2    CO  ...  Toluene  Eth-Benzene  MP-Xylene  O-Xylene   Temp  \
# 0  18.86  12.51  3.24  ...    46.83        12.20      32.47     15.93  16.53
# 1  12.02   3.09  0.92  ...    17.44         3.22       8.83      3.99  15.65
# 2  13.45  16.15  1.26  ...    10.75         1.95       5.38      2.36  21.68
# 3  11.77  19.67  0.82  ...     7.37         1.23       3.72      1.46  26.94
# 4  18.11  13.99  2.30  ...    16.56         7.07      19.55      9.04  23.23
#
#       RH    WS      WD      SR  BP
# 0  95.36  1.37  232.56    2.71 NaN
# 1  96.69  1.22  211.26    7.80 NaN
# 2  76.03  1.22  131.28  129.58 NaN
# 3  57.18  1.14  153.64   75.13 NaN
# 4  69.49  1.01  175.80   10.52 NaN
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (874, 22)

# %%
df.dtypes
# Out:
# From Date       object
# To Date         object
# PM2.5          float64
# PM10           float64
# NO             float64
# NO2            float64
# NOx            float64
# NH3            float64
# SO2            float64
# CO             float64
# Ozone          float64
# Benzene        float64
# Toluene        float64
# Eth-Benzene    float64
# MP-Xylene      float64
# O-Xylene       float64
# Temp           float64
# RH             float64
# WS             float64
# WD             float64
# SR             float64
# BP             float64
# dtype: object

# %%
df.describe()
# Out:
#             PM2.5        PM10          NO         NO2         NOx         NH3  \
# count  869.000000  868.000000  860.000000  860.000000  860.000000  859.000000
# mean    58.301577  105.685657   11.027256   40.187791   29.954174   20.618068
# std     24.196698   42.994135   21.728621   29.086089   30.031332   14.504481
# min      6.260000   20.350000    0.460000    2.340000    4.220000    0.540000
# 25%     40.010000   74.585000    1.660000   18.377500   11.232500   12.620000
# 50%     54.740000   99.935000    3.145000   32.190000   19.695000   17.570000
# 75%     73.130000  130.550000    8.585000   51.992500   34.300000   25.215000
# max    173.220000  266.890000  190.080000  165.960000  221.460000  165.930000
#
#               SO2          CO       Ozone     Benzene     Toluene  \
# count  871.000000  871.000000  869.000000  851.000000  851.000000
# mean    18.127566    1.043330   33.696525    6.102186   14.700341
# std     16.457918    0.818316   25.620082    4.514228   13.807394
# min      0.810000    0.050000    1.870000    0.000000    0.000000
# 25%      8.775000    0.540000   12.040000    2.895000    5.545000
# 50%     13.080000    0.730000   28.750000    4.790000    9.560000
# 75%     21.305000    1.230000   50.130000    7.875000   18.675000
# max    127.680000    5.640000  129.480000   27.150000   79.800000
#
#        Eth-Benzene   MP-Xylene   O-Xylene        Temp          RH          WS  \
# count   849.000000  849.000000  849.00000  871.000000  871.000000  871.000000
# mean      3.768386    9.102521    4.28000   27.055844   63.005832    1.204305
# std       4.609323   11.196165    5.67202    5.951098   15.907537    0.288866
# min       0.070000    0.280000    0.09000   11.640000   27.470000    0.360000
# 25%       0.850000    2.170000    0.88000   22.660000   50.695000    1.010000
# 50%       1.740000    4.360000    1.80000   26.530000   62.310000    1.170000
# 75%       4.580000   11.220000    5.21000   31.175000   75.405000    1.345000
# max      25.130000   66.320000   33.84000   41.720000   97.340000    2.850000
#
#                WD          SR   BP
# count  871.000000  679.000000  0.0
# mean   183.573754  138.549617  NaN
# std     43.831352  173.136754  NaN
# min     76.220000    0.100000  NaN
# 25%    152.570000   10.380000  NaN
# 50%    185.500000   49.260000  NaN
# 75%    218.825000  219.220000  NaN
# max    280.890000  690.670000  NaN

# %%
df.isnull().sum()
# Out:
# From Date        0
# To Date          0
# PM2.5            5
# PM10             6
# NO              14
# NO2             14
# NOx             14
# NH3             15
# SO2              3
# CO               3
# Ozone            5
# Benzene         23
# Toluene         23
# Eth-Benzene     25
# MP-Xylene       25
# O-Xylene        25
# Temp             3
# RH               3
# WS               3
# WD               3
# SR             195
# BP             874
# dtype: int64

# %%
df.drop('BP', axis=1, inplace=True)

# %%
df
# Out:
#             From Date           To Date   PM2.5    PM10     NO     NO2    NOx  \
# 0    01-01-2024 00:00  01-01-2024 04:00  173.22  266.89  65.59   76.85  93.94
# 1    01-01-2024 04:00  01-01-2024 08:00  119.92  203.37   8.42   28.28  22.27
# 2    01-01-2024 08:00  01-01-2024 12:00  110.05  183.18   7.01   36.94  26.06
# 3    01-01-2024 12:00  01-01-2024 16:00  105.07  163.57   5.57   22.86  17.44
# 4    01-01-2024 16:00  01-01-2024 20:00   88.36  138.50  48.31   84.38  83.95
# ..                ...               ...     ...     ...    ...     ...    ...
# 869  24-05-2024 20:00  25-05-2024 00:00   64.54  156.94  14.91  101.72  65.05
# 870  25-05-2024 00:00  25-05-2024 04:00   78.24  137.92   1.79   27.46  15.57
# 871  25-05-2024 04:00  25-05-2024 08:00   48.36   77.67   1.06   12.22   6.95
# 872  25-05-2024 08:00  25-05-2024 12:00   47.24   72.42   1.45   16.79   9.56
# 873  25-05-2024 12:00  25-05-2024 14:00   68.61  111.99   2.11   46.17  25.46
#
#        NH3     SO2    CO  ...  Benzene  Toluene  Eth-Benzene  MP-Xylene  \
# 0    18.86   12.51  3.24  ...    22.20    46.83        12.20      32.47
# 1    12.02    3.09  0.92  ...     9.93    17.44         3.22       8.83
# 2    13.45   16.15  1.26  ...    10.68    10.75         1.95       5.38
# 3    11.77   19.67  0.82  ...     5.74     7.37         1.23       3.72
# 4    18.11   13.99  2.30  ...    10.42    16.56         7.07      19.55
# ..     ...     ...   ...  ...      ...      ...          ...        ...
# 869  39.39   21.61  2.58  ...    12.95    38.43         9.54      26.12
# 870  19.62    9.49  0.68  ...     5.97    16.29         2.26       6.55
# 871  15.61    4.68  0.42  ...     2.51     4.83         0.40       1.17
# 872  17.97   19.65  0.59  ...     2.99     5.95         0.58       1.62
# 873  26.29  113.20  0.53  ...     2.84     2.51         0.28       0.62
#
#      O-Xylene   Temp     RH    WS      WD      SR
# 0       15.93  16.53  95.36  1.37  232.56    2.71
# 1        3.99  15.65  96.69  1.22  211.26    7.80
# 2        2.36  21.68  76.03  1.22  131.28  129.58
# 3        1.46  26.94  57.18  1.14  153.64   75.13
# 4        9.04  23.23  69.49  1.01  175.80   10.52
# ..        ...    ...    ...   ...     ...     ...
# 869     12.23  34.24  51.08  0.75  211.01     NaN
# 870      2.69  31.82  64.39  1.00  151.05     NaN
# 871      0.38  30.53  66.43  1.22  121.61   63.20
# 872      0.62  34.71  60.71  1.00  131.07  528.03
# 873      0.19  38.56  52.32  1.19  114.97  690.67
#
# [874 rows x 21 columns]

# %%
column_name = 'Benzene'
mean_value = df[column_name].mean()
df[column_name].fillna(mean_value, inplace=True)

# %%
columns_to_fill = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Toluene', 'Eth-Benzene', 'MP-Xylene', 'O-Xylene', 'Temp', 'RH', 'WS', 'WD', 'SR']

for column in columns_to_fill:
    if column in df.columns and pd.api.types.is_numeric_dtype(df[column]):
        mean_value = df[column].mean()
        df[column].fillna(mean_value, inplace=True)
    else:
        print(f"Column '{column}' either doesn't exist in the DataFrame or is not numeric.")

print(df.head())
# Out:
#           From Date           To Date   PM2.5    PM10     NO    NO2    NOx  \
# 0  01-01-2024 00:00  01-01-2024 04:00  173.22  266.89  65.59  76.85  93.94
# 1  01-01-2024 04:00  01-01-2024 08:00  119.92  203.37   8.42  28.28  22.27
# 2  01-01-2024 08:00  01-01-2024 12:00  110.05  183.18   7.01  36.94  26.06
# 3  01-01-2024 12:00  01-01-2024 16:00  105.07  163.57   5.57  22.86  17.44
# 4  01-01-2024 16:00  01-01-2024 20:00   88.36  138.50  48.31  84.38  83.95
#
#      NH3    SO2    CO  ...  Benzene  Toluene  Eth-Benzene  MP-Xylene  \
# 0  18.86  12.51  3.24  ...    22.20    46.83        12.20      32.47
# 1  12.02   3.09  0.92  ...     9.93    17.44         3.22       8.83
# 2  13.45  16.15  1.26  ...    10.68    10.75         1.95       5.38
# 3  11.77  19.67  0.82  ...     5.74     7.37         1.23       3.72
# 4  18.11  13.99  2.30  ...    10.42    16.56         7.07      19.55
#
#    O-Xylene   Temp     RH    WS      WD      SR
# 0     15.93  16.53  95.36  1.37  232.56    2.71
# 1      3.99  15.65  96.69  1.22  211.26    7.80
# 2      2.36  21.68  76.03  1.22  131.28  129.58
# 3      1.46  26.94  57.18  1.14  153.64   75.13
# 4      9.04  23.23  69.49  1.01  175.80   10.52
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# From Date      0
# To Date        0
# PM2.5          0
# PM10           0
# NO             0
# NO2            0
# NOx            0
# NH3            0
# SO2            0
# CO             0
# Ozone          0
# Benzene        0
# Toluene        0
# Eth-Benzene    0
# MP-Xylene      0
# O-Xylene       0
# Temp           0
# RH             0
# WS             0
# WD             0
# SR             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df['PM2.5'].hist()
plt.show()

# %%
numerical_columns = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'Eth-Benzene', 'MP-Xylene', 'O-Xylene', 'Temp', 'RH', 'WS', 'WD', 'SR']

num_rows = 4  
num_cols = (len(numerical_columns) - 1) // num_rows + 1

fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 15))

if not isinstance(axes, np.ndarray):
    axes = np.array([axes])

for i, column in enumerate(numerical_columns):
    ax = axes.flatten()[i]
    ax.hist(df[column], bins=20, color='skyblue', edgecolor='black')  
    ax.set_title(column)
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')


for i in range(len(numerical_columns), num_rows * num_cols):
    axes.flatten()[i].axis('off')

plt.tight_layout()
plt.show()

# %%
# List of numerical columns
numerical_columns = ['PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2', 'CO', 'Ozone', 'Benzene', 'Toluene', 'Eth-Benzene', 'MP-Xylene', 'O-Xylene', 'Temp', 'RH', 'WS', 'WD', 'SR']

# Number of rows and columns for subplots
num_rows = 4  # You can adjust this according to the number of columns you want in each row
num_cols = (len(numerical_columns) - 1) // num_rows + 1

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 15))

# Flatten axes if necessary
if not isinstance(axes, np.ndarray):
    axes = np.array([axes])

# Plot box plots for each numerical column
for i, column in enumerate(numerical_columns):
    ax = axes.flatten()[i]
    ax.boxplot(df[column])
    ax.set_title(column)
    ax.set_ylabel('Value')

# Hide empty subplots
for i in range(len(numerical_columns), num_rows * num_cols):
    axes.flatten()[i].axis('off')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Correlation matrix
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 import seaborn as sns
#       3 # Correlation matrix
# ----> 4 corr_matrix = df.corr()
#       5 sns.heatmap(corr_matrix, annot=True)
#       6 plt.show()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: '01-01-2024 00:00'
